# %%
import pickle
filename ="Finalized_model_RandomforestRegresAssign.sav"
#pickle.dump(regressor,open(filename,'wb'))
loaded_model=pickle.load(open("Finalized_model_RandomforestRegresAssign.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
result
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([26608.6408865])
